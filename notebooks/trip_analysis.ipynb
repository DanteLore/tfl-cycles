# %%
import calendar

import matplotlib as mpl
import matplotlib.dates as mdates
import matplotlib.pyplot as plt
import seaborn as sns
from pyspark.sql import SparkSession
from pyspark.sql import types as T

palette = sns.color_palette("colorblind", 20)

spark = (
    SparkSession.builder
        .master("local")
        .appName("TFL Notebook")
        .config('spark.executor.memory', '8G')
        .config('spark.driver.memory', '16G')
        .config('spark.driver.maxResultSize', '10G')
        .config("spark.sql.crossJoin.enabled", "true")
        .getOrCreate()
)


BIKE_POINTS_FILE = "../data/bike-points.csv"

schema = T.StructType([
    T.StructField("idx",       T.IntegerType(), False),
    T.StructField("id",        T.IntegerType(), False),
    T.StructField("name",      T.StringType(),  False),
    T.StructField("latitude",  T.DoubleType(),  False),
    T.StructField("longitude", T.DoubleType(),  False),
    T.StructField("osgb_x",    T.DoubleType(),  False),
    T.StructField("osgb_y",    T.DoubleType(),  False),
    T.StructField("numdocks",  T.LongType(),    False),
    T.StructField("num_bikes", T.LongType(),    False),
    T.StructField("num_empty", T.LongType(),    False)
])
bike_points = spark.read.csv(BIKE_POINTS_FILE, schema=schema, header='true', mode="PERMISSIVE")
bike_points.createOrReplaceTempView("bike_points")

trips = spark.read.parquet("../data/parquet_trip")
trips.createOrReplaceTempView("trips")
trips = spark.sql("""
    select *,
    CASE WHEN start_station_name = end_station_name THEN "Round Trip" ELSE "Point to Point" END AS trip_type
    from trips
""")
trips.createOrReplaceTempView("trips")

trips.limit(10).toPandas()
# Out:
#    rental_id  duration  bike_id  end_station_id  \
# 0   52539009       480      962             507
# 1   52539022       780    13418             689
# 2   52539024       360    12009             512
# 3   52539441       960     1997             620
# 4   52539789       660     4883             217
# 5   52539935       240     9661             737
# 6   52540057       840     1341             552
# 7   52540153      1200     7677              54
# 8   52540271       420     4955              73
# 9   52540607       600    10280             229
#
#                     end_station_name  start_station_id  \
# 0     Clarkson Street, Bethnal Green               401
# 1     Spanish Road, Clapham Junction               573
# 2    Pritchard's Road, Bethnal Green               479
# 3             Surrey Lane, Battersea               631
# 4  Wormwood Street, Liverpool Street               154
# 5      Fulham Broadway, Walham Green               723
# 6            Watney Street, Shadwell               717
# 7              Golden Lane, Barbican               425
# 8     Old Street Station, St. Luke's               748
# 9            Whitehall Place, Strand               217
#
#                   start_station_name            start_ts  start_year  \
# 0          Columbia Road, Shoreditch 2016-04-01 00:30:00        2016
# 1     Limerston Street, West Chelsea 2016-04-01 00:34:00        2016
# 2         Pott Street, Bethnal Green 2016-04-01 00:35:00        2016
# 3     Battersea Park Road, Nine Elms 2016-04-01 04:25:00        2016
# 4       Waterloo Station 3, Waterloo 2016-04-01 06:35:00        2016
# 5        Stephendale Road, Sands End 2016-04-01 06:50:00        2016
# 6          Dunston Road , Haggerston 2016-04-01 06:58:00        2016
# 7   Harrington Square 2, Camden Town 2016-04-01 07:05:00        2016
# 8    Hertford Road, De Beauvoir Town 2016-04-01 07:12:00        2016
# 9  Wormwood Street, Liverpool Street 2016-04-01 07:28:00        2016
#
#    start_month  start_day  start_day_of_week  start_hour              end_ts  \
# 0            4          1                  6           0 2016-04-01 00:38:00
# 1            4          1                  6           0 2016-04-01 00:47:00
# 2            4          1                  6           0 2016-04-01 00:41:00
# 3            4          1                  6           4 2016-04-01 04:41:00
# 4            4          1                  6           6 2016-04-01 06:46:00
# 5            4          1                  6           6 2016-04-01 06:54:00
# 6            4          1                  6           6 2016-04-01 07:12:00
# 7            4          1                  6           7 2016-04-01 07:25:00
# 8            4          1                  6           7 2016-04-01 07:19:00
# 9            4          1                  6           7 2016-04-01 07:38:00
#
#    end_year  end_month  end_day  end_day_of_week  end_hour       trip_type
# 0      2016          4        1                6         0  Point to Point
# 1      2016          4        1                6         0  Point to Point
# 2      2016          4        1                6         0  Point to Point
# 3      2016          4        1                6         4  Point to Point
# 4      2016          4        1                6         6  Point to Point
# 5      2016          4        1                6         6  Point to Point
# 6      2016          4        1                6         7  Point to Point
# 7      2016          4        1                6         7  Point to Point
# 8      2016          4        1                6         7  Point to Point
# 9      2016          4        1                6         7  Point to Point

# %% [markdown]
# # Trip counts by year

# %%
trips.createOrReplaceTempView("trips")
sdf = spark.sql("""
    select start_year, count(*) as cnt
    from trips 
    group by start_year
    order by start_year asc
""")

df = sdf.toPandas()

ax = df.plot(kind='bar', color=palette, legend=None, x='start_year', y='cnt', width=0.9, figsize=(8,5))
ax.get_yaxis().set_major_formatter(mpl.ticker.FuncFormatter(lambda x, p: format(int(x)/1000)))
plt.title("TFL Cycle usage per year", fontsize=18)
plt.ylabel("Number of trips (thousands)", fontsize=12)
plt.xlabel('')
plt.show()

# %% [markdown]
# # Trip counts by month

# %%
trips.createOrReplaceTempView("trips")
sdf = spark.sql("""
    select start_year, start_month, count(*) as cnt, avg(duration) as duration 
    from trips 
    group by start_year, start_month
    order by start_year asc, start_month asc
""")

df = sdf.toPandas()

fig, ax = plt.subplots(figsize=(10, 6))
plt.xticks(range(0,13), calendar.month_abbr)

ax.get_yaxis().set_major_formatter(mpl.ticker.FuncFormatter(lambda x, p: format(int(x)/1000)))

for key, grp in df.groupby(['start_year']):
    ax = grp.plot(ax=ax, kind='line', x='start_month', y='cnt', label=key, linewidth=4.0)

plt.title("TFL Cycle Journeys", fontsize=18)
plt.xlabel('')
plt.ylabel('Number of trips (thousands)', fontsize=12)
plt.legend(loc='best')
plt.show()

# %% [markdown]
# # Busiest Bike Stations

# %%
trips.createOrReplaceTempView("trips")
start_df = spark.sql("""
    select start_station_name, count(*) as cnt
    from trips 
    group by start_station_name
    order by cnt desc
""").limit(10).toPandas()

start_df = start_df.sort_values(by=['cnt'], ascending=True)

ax = start_df.plot(kind='barh', color=palette, legend=None, x='start_station_name', y='cnt', width=0.9, figsize=(10,5))
ax.get_xaxis().set_major_formatter(mpl.ticker.FuncFormatter(lambda x, p: format(int(x)/1000)))
plt.title("Most Used Bike Stations - Start", fontsize=18)
plt.xlabel("Number of trips starting here (thousands)", fontsize=12)
plt.ylabel('')
plt.show()

trips.createOrReplaceTempView("trips")
end_df = spark.sql("""
    select end_station_name, count(*) as cnt
    from trips 
    group by end_station_name
    order by cnt desc
""").limit(10).toPandas()

end_df = end_df.sort_values(by=['cnt'], ascending=True)

ax = end_df.plot(kind='barh', color=palette, legend=None, x='end_station_name', y='cnt', width=0.9, figsize=(10,5))
ax.get_xaxis().set_major_formatter(mpl.ticker.FuncFormatter(lambda x, p: format(int(x)/1000)))
plt.title("Most Used Bike Stations - End", fontsize=18)
plt.xlabel("Number of trips ending here (thousands)", fontsize=12)
plt.ylabel('')
plt.show()

# %% [markdown]
# # Most Popular Trips

# %%
trips.createOrReplaceTempView("trips")
trip_counts = spark.sql("""
    select start_station_name, end_station_name, count(*) as trip_count, sum(duration) as duration
    from trips 
    group by start_station_name, end_station_name
    order by trip_count desc
""")
trip_counts.createOrReplaceTempView("trip_counts")

# Would be nice: https://plot.ly/python/filled-chord-diagram/

trip_counts.limit(10).toPandas()
# Out:
#                              start_station_name  \
# 0                   Hyde Park Corner, Hyde Park
# 1                        Albert Gate, Hyde Park
# 2           Black Lion Gate, Kensington Gardens
# 3  Aquatic Centre, Queen Elizabeth Olympic Park
# 4                  Triangle Car Park, Hyde Park
# 5                         Park Lane , Hyde Park
# 6               Palace Gate, Kensington Gardens
# 7                   Hyde Park Corner, Hyde Park
# 8                    Wellington Arch, Hyde Park
# 9           Black Lion Gate, Kensington Gardens
#
#                                end_station_name  trip_count   duration
# 0                   Hyde Park Corner, Hyde Park       93142  312174952
# 1                        Albert Gate, Hyde Park       51579  149492431
# 2           Black Lion Gate, Kensington Gardens       50192  162254498
# 3  Aquatic Centre, Queen Elizabeth Olympic Park       48011  169850578
# 4                  Triangle Car Park, Hyde Park       39228  116826205
# 5                         Park Lane , Hyde Park       27147   95697513
# 6               Palace Gate, Kensington Gardens       24275   69116069
# 7                        Albert Gate, Hyde Park       19168   51922373
# 8                    Wellington Arch, Hyde Park       19103   55134240
# 9               Palace Gate, Kensington Gardens       18942   28811298

# %% [markdown]
# # Least Popular Trips

# %%
trip_counts.orderBy("trip_count").limit(10).toPandas()
# Out:
#                             start_station_name  \
# 0              St. Chad's Street, King's Cross
# 1                        Disraeli Road, Putney
# 2             Plough Terrace, Clapham Junction
# 3         Kensington Church Street, Kensington
# 4             Simpson Street, Clapham Junction
# 5                       Sidney Road, Stockwell
# 6  Paddington Green Police Station, Paddington
# 7                   Southwark Street, Bankside
# 8            Imperial Wharf Station, Sands End
# 9         Podium, Queen Elizabeth Olympic Park
#
#                   end_station_name  trip_count  duration
# 0      Austin Road, Battersea Park           1      2760
# 1  Tavistock Street, Covent Garden           1      2580
# 2         Clifton Road, Maida Vale           1      4440
# 3           Burdett Road, Mile End           1      5760
# 4    St Martins Close, Camden Town           1    577920
# 5     Shoreditch Court, Haggerston           1      3000
# 6    Jubilee Crescent, Cubitt Town           1      3180
# 7     Hardwick Street, Clerkenwell           1      1260
# 8    Lisson Grove, St. John's Wood           1      2400
# 9    Fulham Broadway, Walham Green           1      5340

# %%
trips.createOrReplaceTempView("trips")
df = (
    spark.sql("""
        select trip_type, count(*) as trip_count, sum(duration) as duration from trips
        group by trip_type
    """)
).toPandas()

plt.subplots_adjust(left=0.1, right=0.9, top=0.9, bottom=0.1)

plt.pie(df['duration'], labels=df['trip_type'], shadow=False, startangle=45, explode=(0.25, 0), autopct='%1.1f%%',
        colors=sns.color_palette("pastel", 4), wedgeprops={'linewidth' : 1 , 'edgecolor' : 'black'})
plt.title("Total duration of trips by type", fontsize=16)
plt.axis('equal')
plt.show()

plt.pie(df['trip_count'], labels=df['trip_type'], shadow=False, startangle=45, explode=(0.25, 0), autopct='%1.1f%%',
        wedgeprops={'linewidth' : 1 , 'edgecolor' : 'black'}, colors=sns.color_palette("bright", 4)[2:])
plt.title("Number of trips by type", fontsize=16)
plt.axis('equal')
plt.show()

# %%
trips.createOrReplaceTempView("trips")
round_trip_durations = (
    spark.sql("""select duration from trips where trip_type == 'Round Trip' and duration < 7200""")
).toPandas()

p2p_trip_durations = (
    spark.sql("""select duration from trips where trip_type != 'Round Trip' and duration < 7200""")
).toPandas()

# %%
def format_number_for_axis(value, tick_number):
    return "{0:0.0f}min".format(value / 60)

plt.subplots(figsize=(14, 8))

ax = sns.distplot(round_trip_durations['duration'], label='Round Trip')
sns.distplot(p2p_trip_durations['duration'], ax=ax, label='Point to Point')

ax.xaxis.set_major_formatter(plt.FuncFormatter(format_number_for_axis))
ax.yaxis.set_visible(False)
ax.set_xlim([0, 7200])

plt.title("", fontsize=18)
plt.legend(loc='upper right', fontsize=18)
plt.axvline(0, color='black')
plt.xlabel("Trip Duration")
plt.ylabel("")
plt.show()
