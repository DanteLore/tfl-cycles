# %%
import geopandas as gpd
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
from shapely.geometry import Point
import mplleaflet

BIKE_POINTS_FILE = "../data/bike-points.csv"

bp_df = pd.read_csv(BIKE_POINTS_FILE)
geometry = [Point(xy) for xy in zip(bp_df['longitude'], bp_df['latitude'])]
gdf = gpd.GeoDataFrame(bp_df, geometry=geometry)

# %%
fig,ax=plt.subplots(figsize=(10,10))

gdf.plot(ax=ax, markersize=20, color='Red', marker='o')

mplleaflet.display(fig=fig, crs=gdf.crs, tiles='cartodb_positron')
# Out:
# <iframe src="data:text/html;base64,..." width="100%" height="600"></iframe>
